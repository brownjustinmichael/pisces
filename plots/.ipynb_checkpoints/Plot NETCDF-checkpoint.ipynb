# %%
import IPython.html.widgets
import netCDF4
import numpy as np
import numpy.ma as ma

# %%
import matplotlib.pyplot as plt

# JSAnimation import available at https://github.com/jakevdp/JSAnimation
from JSAnimation import IPython_display
from matplotlib import animation

dataset = netCDF4.Dataset ('../sims/layers/output/test_00.cdf', 'r')
# dataset2 = netCDF4.Dataset ('../sims/example/output/sc_gwave_t_01.cdf', 'r')
# dataset3 = netCDF4.Dataset ('../sims/example/output/sc_gwave_02.cdf', 'r')

ts = {}
per = 2

# xdata = np.concatenate ((dataset.variables ["x"], dataset2.variables ["x"]), 2)
# zdata = np.concatenate ((dataset.variables ["z"], dataset2.variables ["z"]), 2)
# tdata = np.concatenate ((dataset.variables ["T"], dataset2.variables ["T"]), 2)
# divdata = np.concatenate ((dataset.variables ["div"], dataset2.variables ["div"]), 2)

xdata = dataset.variables ["x"]
zdata = dataset.variables ["z"]
tdata = dataset.variables ["T"]
divdata = dataset.variables ["div"]

x = xdata [0]
y = zdata [0]
t = tdata [0]
d = divdata [0]

ts [0] = {"div": np.atleast_2d (d.T), "x": np.atleast_2d (x.T), "z": np.atleast_2d (y.T)}

# # create a simple animation
fig = plt.figure(figsize = (8, 6))
ax = plt.subplot (111)
p = ax.pcolormesh (ts [0] ['x'], ts [0] ['z'], ts [0] ['div'])
cb = [plt.colorbar (p)]

ax.set_xlim ((x [0,0], x [-1,-1]))
ax.set_ylim ((y [0,0], y [-1,-1]))
# x = np.linspace(0, 10, 1000)

def animate (i, *args):
    i *= per
    if i not in ts:
        x = xdata [i]
        y = zdata [i]
        t = tdata [i]
        
        ts [i] = {"div": np.atleast_2d (t.T), "x": np.atleast_2d (x.T), "z": np.atleast_2d (y.T)}
    p = ax.pcolormesh (ts [i] ['x'], ts [i] ['z'], ts [i] ['div'])
    cb [0].remove ()
    cb [0] = fig.colorbar (p)

    return p

def init():
    pass

animation.FuncAnimation(fig, animate, init_func=init,
                        frames=len (dataset.dimensions ['record']) // per, interval=200, blit=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-c389398d5284> in <module>()
#      57
#      58 animation.FuncAnimation(fig, animate, init_func=init,
# ---> 59                         frames=len (dataset.dimensions ['record']) // per, interval=200, blit=True)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/IPython/core/displayhook.py in __call__(self, result)
#     250             self.start_displayhook()
#     251             self.write_output_prompt()
# --> 252             format_dict, md_dict = self.compute_format_data(result)
#     253             self.write_format_data(format_dict, md_dict)
#     254             self.update_user_ns(result)
#
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/IPython/core/displayhook.py in compute_format_data(self, result)
#     152
# ...

# %%
# %matplotlib inline

# %%
import math

# %%
math.e**-12
# Out:
# 6.144212353328214e-06

# %%
p

# %%
plt.style.use ("dark_background")

datasets = []
datasets.append (netCDF4.Dataset ('../sims/layers/output_2/sc_layer_00.cdf', 'r'))
datasets.append (netCDF4.Dataset ('../sims/layers/output_2/sc_layer_01.cdf', 'r'))
datasets.append (netCDF4.Dataset ('../sims/layers/output_2/sc_layer_02.cdf', 'r'))
datasets.append (netCDF4.Dataset ('../sims/layers/output_2/sc_layer_03.cdf', 'r'))

ts = {}
per = 2

xdata = []
zdata = []
tdata = []
divdata = []

for dataset in datasets:
    xdata.append (dataset.variables ["x"])
    zdata.append (dataset.variables ["z"])
    tdata.append (dataset.variables ["S"])
    divdata.append (dataset.variables ["div"])

record = -60
    
x = sum ([ma.getdata (data [record]) for data in xdata])
y = sum ([ma.getdata (data [record]) for data in zdata])
t = sum ([ma.getdata (data [record]) for data in tdata])
d = sum ([ma.getdata (data [record]) for data in divdata])


# # create a simple animation
fig = plt.figure(figsize = (5, 16))
ax = plt.subplot (111)
p = ax.pcolormesh (x.T, y.T, t.T, vmin = -max (np.max (np.abs (t), np.min (np.abs (t)))), vmax = max (np.max (np.abs (t), np.min (np.abs (t)))), cmap = plt.get_cmap ("RdBu"))

cb = plt.colorbar (p)

ax.set_xlim ((x [0,0], x [-1,-1]))
ax.set_ylim ((y [0,0], y [-1,-1]))

ax.set_xlabel ("x")
ax.set_ylabel ("z")
cb.set_label ("S")
# x = np.linspace(0, 10, 1000)

lines = [ax.axhline (i, -200, 200, lw = 1.0) for i in y [0,::10].flat]
vlines = [ax.axvline (i, -200, 200, lw = 1.0) for i in x [::10,0].flat]
