# %%
import IPython.html.widgets
import netCDF4
import numpy as np
import h5py

# %%
import matplotlib.pyplot as plt

# JSAnimation import available at https://github.com/jakevdp/JSAnimation
from JSAnimation import IPython_display
from matplotlib import animation

dataset = netCDF4.Dataset ('../sims/example/output/sc_gwave_00.cdf', 'r')
dataset2 = netCDF4.Dataset ('../sims/example/output/sc_gwave_01.cdf', 'r')
ts = {}
per = 1

xdata = np.concatenate ((dataset.variables ["x"], dataset2.variables ["x"]), 2)
zdata = np.concatenate ((dataset.variables ["z"], dataset2.variables ["z"]), 2)
tdata = np.concatenate ((dataset.variables ["T"], dataset2.variables ["T"]), 2)

x = xdata [0]
y = zdata [0]
t = tdata [0]

ts [0] = {"temperature": np.atleast_2d (t.T), "x": np.atleast_2d (x.T), "z": np.atleast_2d (y.T)}

# # create a simple animation
fig = plt.figure(figsize = (10, 10))
ax = plt.subplot (111)
p = ax.pcolormesh (ts [0] ['x'], ts [0] ['z'], ts [0] ['temperature'])
cb = [plt.colorbar (p)]

ax.set_xlim ((x [0,0], x [-1,-1]))
ax.set_ylim ((y [0,0], y [-1,-1]))
# x = np.linspace(0, 10, 1000)

def animate (i, *args):
    i *= per
    if i not in ts:
        x = xdata [i]
        y = zdata [i]
        t = tdata [i]
        
        ts [i] = {"temperature": np.atleast_2d (t.T), "x": np.atleast_2d (x.T), "z": np.atleast_2d (y.T)}
    p = ax.pcolormesh (ts [i] ['x'], ts [i] ['z'], ts [i] ['temperature'])
    cb [0].remove ()
    cb [0] = fig.colorbar (p)

    return p

def init():
    pass

animation.FuncAnimation(fig, animate, init_func=init,
                        frames=len (dataset.dimensions ['record']) / per, interval=200, blit=True)
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
# ...

# %%
# %matplotlib inline
